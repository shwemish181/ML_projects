# 17364           2  0.18  0.2121  0.64     0.1045      13         144  157
# 17365           2  0.20  0.2121  0.69     0.1343      33          87  120
# 17366           2  0.22  0.2273  0.60     0.1940      43         114  157
# 17367           2  0.24  0.2273  0.56     0.1940      52         172  224
# 17368           2  0.26  0.2576  0.44     0.1642      38         165  203
# 17369           2  0.28  0.2727  0.45     0.2239      62         185  247
# 17370           2  0.28  0.2879  0.45     0.1343      69         246  315
# 17371           2  0.26  0.2576  0.48     0.1940      30         184  214
# 17372           2  0.26  0.2879  0.48     0.0896      14         150  164
# 17373           2  0.26  0.2727  0.48     0.1343      10         112  122
# 17374           2  0.26  0.2576  0.60     0.1642      11         108  119
# 17375           2  0.26  0.2576  0.60     0.1642       8          81   89
# 17376           1  0.26  0.2576  0.60     0.1642       7          83   90
# 17377           1  0.26  0.2727  0.56     0.1343      13          48   61
# 17378           1  0.26  0.2727  0.65     0.1343      12          37   49
#
# [17379 rows x 17 columns]

# %%
#lets chcek the there are null values in dataset or not
df_bikes.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
#we can drop "instant" column as it is just Serial number kind of thing
df_bikes.drop(columns=["instant"],inplace=True)

# %%
#lets chcek the datatypes
df_bikes.dtypes
# Out:
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                int64
# weekday                int64
# workingday             int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
#lets chcek the correlation matrix
df_bikes.corr()
# Out:
#               season        yr      mnth        hr   holiday   weekday  \
# season      1.000000 -0.010742  0.830386 -0.006117 -0.009585 -0.002335
# yr         -0.010742  1.000000 -0.010473 -0.003867  0.006692 -0.004485
# mnth        0.830386 -0.010473  1.000000 -0.005772  0.018430  0.010400
# hr         -0.006117 -0.003867 -0.005772  1.000000  0.000479 -0.003498
# holiday    -0.009585  0.006692  0.018430  0.000479  1.000000 -0.102088
# weekday    -0.002335 -0.004485  0.010400 -0.003498 -0.102088  1.000000
# workingday  0.013743 -0.002196 -0.003477  0.002285 -0.252471  0.035955
# weathersit -0.014524 -0.019157  0.005400 -0.020203 -0.017036  0.003311
# temp        0.312025  0.040913  0.201691  0.137603 -0.027340 -0.001795
# atemp       0.319380  0.039222  0.208096  0.133750 -0.030973 -0.008821
# hum         0.150625 -0.083546  0.164411 -0.276498 -0.010588 -0.037158
# windspeed  -0.149773 -0.008740 -0.135386  0.137252  0.003988  0.011502
# casual      0.120206  0.142779  0.068457  0.301202  0.031564  0.032721
# registered  0.174226  0.253684  0.122273  0.374141 -0.047345  0.021578
# cnt         0.178056  0.250495  0.120638  0.394071 -0.030927  0.026900
#
#             workingday  weathersit      temp     atemp       hum  windspeed  \
# season        0.013743   -0.014524  0.312025  0.319380  0.150625  -0.149773
# yr           -0.002196   -0.019157  0.040913  0.039222 -0.083546  -0.008740
# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))
sns.pointplot(x="hr",y="cnt",hue="season",data=df_bikes)
plt.show()
#this is how the bikes count changes hourly and along with season
#we can see count is more suring fall for most of the hours of the day compared to thers season

# %%
#lets chcek the average count season wise also
sns.barplot(x="season",y="cnt",data=df_bikes)
plt.show()
#during spring average count is least

# %%
#Lest compare the average count year wise
sns.barplot(x="yr",y="cnt",data=df_bikes)
plt.show()
#there considerabe increase in 2012 from 2011 that means people are adopting to bike rental systems

# %%
#lets chcek the average count based on "working day"
sns.barplot(x="workingday",y="cnt",data=df_bikes)
plt.show()
#This means irrespecttive of working day or not bikes are being rented almost equally

# %%
#lets chcek how count changes with with days in a week
plt.figure(figsize=(20,5))
sns.pointplot(x="hr",y="cnt",hue="weekday",data=df_bikes)
plt.show()

# %%
#lets chcek in which hour of the day average count is more
plt.figure(figsize=(20,5))
sns.barplot(x="hr",y="cnt",data=df_bikes)
plt.show()

# %%
#lets chcek in which month the year average count is more
plt.figure(figsize=(20,5))
sns.barplot(x="mnth",y="cnt",data=df_bikes)
plt.show()

# %%
#lets chcek the average count based on weather situation
sns.barplot(x="weathersit",y="cnt",data=df_bikes)
plt.show()

# %%
#lets chcek the skewnes in the dataset
df_bikes.skew()
#skewness looks fine continuous type of variables in input
# Out:
# season       -0.005416
# yr           -0.010243
# mnth         -0.009253
# hr           -0.010680
# holiday       5.638538
# weekday      -0.002998
# workingday   -0.785258
# weathersit    1.228047
# temp         -0.006021
# atemp        -0.090429
# hum          -0.111287
# windspeed     0.574905
# casual        2.499237
# registered    1.557904
# cnt           1.277412
# dtype: float64

# %%
#Lets seprate the input and ouput variable
df_x=df_bikes.drop(columns=["casual","registered","cnt","dteday"])
y=df_bikes[["cnt"]]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(df_x)
x=sc.transform(df_x)
# Out:
# F:\anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# F:\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,df_x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
#lets make a function which evaluates the model using cross_val_score
from sklearn.model_selection import cross_val_score
def model_evaluation(model,x,y):
    c_scores=cross_val_score(model,x,y,cv=5,scoring="r2")
    print("Mean r2 score for regressor: ",c_scores.mean())
    print("standard deviation in r2 score for regressor: ",c_scores.std())
    print(c_scores)

# %%
#using Decision Trees
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
maxr2_score(dtr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.8929249336045975
# r2 score corresponding to  43  is  0.8967301033366096
# r2 score corresponding to  44  is  0.8797290498188709
# r2 score corresponding to  45  is  0.8967214122547486
# r2 score corresponding to  46  is  0.8759094579153713
# r2 score corresponding to  47  is  0.892239190690198
# r2 score corresponding to  48  is  0.8962200055032713
# r2 score corresponding to  49  is  0.8900494594103231
# r2 score corresponding to  50  is  0.8937905308528293
# r2 score corresponding to  51  is  0.8768074021364209
# r2 score corresponding to  52  is  0.8959617367245214
# r2 score corresponding to  53  is  0.896887014332329
# r2 score corresponding to  54  is  0.9017221512097952
# r2 score corresponding to  55  is  0.8965689937264943
# r2 score corresponding to  56  is  0.9030564511806685
# r2 score corresponding to  57  is  0.900960891387474
# r2 score corresponding to  58  is  0.8997619093942943
# r2 score corresponding to  59  is  0.8924882234462317
# r2 score corresponding to  60  is  0.8910018419126743
# r2 score corresponding to  61  is  0.8972711877046198
# r2 score corresponding to  62  is  0.8870804921937354
# r2 score corresponding to  63  is  0.8926538478443431
# r2 score corresponding to  64  is  0.9015424791440069
# r2 score corresponding to  65  is  0.8830557025317256
# r2 score corresponding to  66  is  0.8968323706682391
# r2 score corresponding to  67  is  0.8949875744953668
# r2 score corresponding to  68  is  0.8953810828339073
# r2 score corresponding to  69  is  0.8879631392166717
# r2 score corresponding to  70  is  0.8807405150844295
# r2 score corresponding to  71  is  0.8928043997819336
# r2 score corresponding to  72  is  0.8966535592200859
# r2 score corresponding to  73  is  0.8888981862937289
# r2 score corresponding to  74  is  0.9025214291956511
# r2 score corresponding to  75  is  0.8855812949996306
# r2 score corresponding to  76  is  0.8904477229582957
# r2 score corresponding to  77  is  0.8956336775790698
# r2 score corresponding to  78  is  0.9014829586359995
# r2 score corresponding to  79  is  0.8926916896745565
# r2 score corresponding to  80  is  0.9021326539704447
# r2 score corresponding to  81  is  0.9080299780349619
# r2 score corresponding to  82  is  0.8895682910026255
# r2 score corresponding to  83  is  0.9036075850339974
# r2 score corresponding to  84  is  0.8929941841818604
# r2 score corresponding to  85  is  0.8776843187333485
# r2 score corresponding to  86  is  0.8849651167039285
# r2 score corresponding to  87  is  0.8883031496752101
# r2 score corresponding to  88  is  0.8823261915084895
# r2 score corresponding to  89  is  0.8942906970708924
# r2 score corresponding to  90  is  0.8879900774029406
# r2 score corresponding to  91  is  0.9012151411223895
# r2 score corresponding to  92  is  0.8793649020818232
# r2 score corresponding to  93  is  0.8818784185927782
# r2 score corresponding to  94  is  0.9010209895204695
# r2 score corresponding to  95  is  0.8927641024390599
# r2 score corresponding to  96  is  0.889186337293737
# r2 score corresponding to  97  is  0.8870729845083055
# r2 score corresponding to  98  is  0.8949374189562376
# r2 score corresponding to  99  is  0.8924912553008191
# max r2 score corresponding to  81  is  0.9080299780349619
# 81

# %%
#Lets chcek KNN
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
knr=KNeighborsRegressor()
parameters = {"n_neighbors":range(2,30)}
clf = GridSearchCV(knr, parameters, cv=5,scoring="r2")
clf.fit(x, y)
clf.best_params_
# Out:
# {'n_neighbors': 16}

# %%
knr=KNeighborsRegressor(n_neighbors=16)
maxr2_score(knr,x,y)
# Out:
# r2 score corresponding to  42  is  0.6249436270832995
# r2 score corresponding to  43  is  0.6097335939134132
# r2 score corresponding to  44  is  0.6188668324440638
# r2 score corresponding to  45  is  0.6121449599832813
# r2 score corresponding to  46  is  0.5954066198582051
# r2 score corresponding to  47  is  0.619511725281388
# r2 score corresponding to  48  is  0.6144351284038465
# r2 score corresponding to  49  is  0.6081601769202369
# r2 score corresponding to  50  is  0.5966938238170658
# r2 score corresponding to  51  is  0.6113473553694917
# r2 score corresponding to  52  is  0.604906692849265
# r2 score corresponding to  53  is  0.5929368539114303
# r2 score corresponding to  54  is  0.6115259596818072
# r2 score corresponding to  55  is  0.6147576447541799
# r2 score corresponding to  56  is  0.6279609616457422
# r2 score corresponding to  57  is  0.6109421213099324
# r2 score corresponding to  58  is  0.6002116517446454
# r2 score corresponding to  59  is  0.61673604391076
# r2 score corresponding to  60  is  0.5992506837026945
# r2 score corresponding to  61  is  0.6119771198348779
# r2 score corresponding to  62  is  0.6122381741423125
# r2 score corresponding to  63  is  0.6106550064485041
# r2 score corresponding to  64  is  0.625222669833157
# r2 score corresponding to  65  is  0.5961185157207893
# r2 score corresponding to  66  is  0.6240347555230857
# r2 score corresponding to  67  is  0.612730221370616
# r2 score corresponding to  68  is  0.6181827976595305
# r2 score corresponding to  69  is  0.6258492842668276
# r2 score corresponding to  70  is  0.597044614588323
# r2 score corresponding to  71  is  0.607226531198394
# r2 score corresponding to  72  is  0.6149007317006653
# r2 score corresponding to  73  is  0.6119913293723509
# r2 score corresponding to  74  is  0.6083032863179185
# r2 score corresponding to  75  is  0.6004815780731727
# r2 score corresponding to  76  is  0.6099572239373532
# r2 score corresponding to  77  is  0.5974288301259423
# r2 score corresponding to  78  is  0.6168829921120658
# r2 score corresponding to  79  is  0.5927097915995969
# r2 score corresponding to  80  is  0.6241412809491564
# r2 score corresponding to  81  is  0.6192341188460565
# r2 score corresponding to  82  is  0.621112740601393
# r2 score corresponding to  83  is  0.598603277073505
# r2 score corresponding to  84  is  0.6152718966202961
# r2 score corresponding to  85  is  0.6152954645662763
# r2 score corresponding to  86  is  0.6020795445940259
# r2 score corresponding to  87  is  0.5932680372704243
# r2 score corresponding to  88  is  0.6087423293924694
# r2 score corresponding to  89  is  0.6188935417250954
# r2 score corresponding to  90  is  0.5857933913050757
# r2 score corresponding to  91  is  0.6082324695214061
# r2 score corresponding to  92  is  0.5978941597586003
# r2 score corresponding to  93  is  0.5999579566166461
# r2 score corresponding to  94  is  0.6183397587011905
# r2 score corresponding to  95  is  0.612915519358491
# r2 score corresponding to  96  is  0.5854147007491568
# r2 score corresponding to  97  is  0.5968085266568952
# r2 score corresponding to  98  is  0.5943911797609611
# r2 score corresponding to  99  is  0.6181413855620312
# max r2 score corresponding to  56  is  0.6279609616457422
# 56

# %%
#lets use ensemble model Random forets
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings("ignore")
rfr=RandomForestRegressor()
parameters = {"n_estimators":[10,100,500]}
clf = GridSearchCV(rfr, parameters, cv=5,scoring="r2")
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'n_estimators': 100}

# %%
rfr=RandomForestRegressor(n_estimators=100)
maxr2_score(rfr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.9436761896542253
# r2 score corresponding to  43  is  0.9459828999389424
# r2 score corresponding to  44  is  0.9404261464616057
# r2 score corresponding to  45  is  0.9400962668219467
# r2 score corresponding to  46  is  0.9406742578955808
# r2 score corresponding to  47  is  0.9420595984334199
# r2 score corresponding to  48  is  0.9422674743730778
# r2 score corresponding to  49  is  0.9434438851971059
# r2 score corresponding to  50  is  0.9449640601195811
# r2 score corresponding to  51  is  0.9402436905436196
# r2 score corresponding to  52  is  0.9445544008116735
# r2 score corresponding to  53  is  0.9444988677073297
# r2 score corresponding to  54  is  0.9475906821706276
# r2 score corresponding to  55  is  0.9458493317456743
# r2 score corresponding to  56  is  0.9462990418979171
# r2 score corresponding to  57  is  0.9493825002011756
# r2 score corresponding to  58  is  0.9453737791073594
# r2 score corresponding to  59  is  0.9490971025656818
# r2 score corresponding to  60  is  0.9410786639836831
# r2 score corresponding to  61  is  0.9487975245284448
# r2 score corresponding to  62  is  0.9445788560257985
# r2 score corresponding to  63  is  0.9444269387023909
# r2 score corresponding to  64  is  0.9467478778506818
# r2 score corresponding to  65  is  0.9372757997720629
# r2 score corresponding to  66  is  0.9426840172205144
# r2 score corresponding to  67  is  0.9466867584480775
# r2 score corresponding to  68  is  0.939993418650027
# r2 score corresponding to  69  is  0.9438962520800683
# r2 score corresponding to  70  is  0.9378529820259686
# r2 score corresponding to  71  is  0.9351382739541266
# r2 score corresponding to  72  is  0.9452911259160428
# r2 score corresponding to  73  is  0.944301623940143
# r2 score corresponding to  74  is  0.9466948712234576
# r2 score corresponding to  75  is  0.9430681876814155
# r2 score corresponding to  76  is  0.9452970567091248
# r2 score corresponding to  77  is  0.9452472694915807
# r2 score corresponding to  78  is  0.9494704574131032
# r2 score corresponding to  79  is  0.9425751776443649
# r2 score corresponding to  80  is  0.9461587683482222
# r2 score corresponding to  81  is  0.9473478149895997
# r2 score corresponding to  82  is  0.944488494916928
# r2 score corresponding to  83  is  0.9462524165096836
# r2 score corresponding to  84  is  0.9422433845935446
# r2 score corresponding to  85  is  0.9411150411842235
# r2 score corresponding to  86  is  0.9403215052696282
# r2 score corresponding to  87  is  0.9448466326746391
# r2 score corresponding to  88  is  0.9381901324678421
# r2 score corresponding to  89  is  0.9478911411734565
# r2 score corresponding to  90  is  0.9454505335340403
# r2 score corresponding to  91  is  0.9503924005089959
# r2 score corresponding to  92  is  0.9352539889530653
# r2 score corresponding to  93  is  0.9360679678854303
# r2 score corresponding to  94  is  0.9461399339382166
# r2 score corresponding to  95  is  0.9455668976373579
# r2 score corresponding to  96  is  0.9456461846978883
# r2 score corresponding to  97  is  0.9438685921537971
# r2 score corresponding to  98  is  0.9424663670643616
# r2 score corresponding to  99  is  0.9467521142899858
# max r2 score corresponding to  91  is  0.9503924005089959
# 91

# %% [markdown]
# Lets chcek the cross val scores of above models

# %%
print("Decision Tree\n\n")
model_evaluation(dtr,df_x,y)
# Out:
# Decision Tree
#
#
# Mean r2 score for regressor:  0.6317512846526765
# standard deviation in r2 score for regressor:  0.23325823185352162
# [0.29407057 0.78552972 0.40662589 0.83192468 0.84060556]

# %%
print("Random Forest\n\n")
model_evaluation(rfr,df_x,y)
# Out:
# Random Forest
#
#
# Mean r2 score for regressor:  0.8043842972786571
# standard deviation in r2 score for regressor:  0.10274087827786862
# [0.66950519 0.87229748 0.68898926 0.89168593 0.89944363]

# %%
#Based on above scores we will choose random forest as our final algo
x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = 91,test_size=0.20)
rfr.fit(x_train,y_train)
y_pred = rfr.predict(x_test)

# %%
#Lets find the rmse and r2_score using sklearn.metrics for random forest model
print("MSE is: ",mean_squared_error(y_test,y_pred))
print("r2_score is: ",r2_score(y_test,y_pred))
# Out:
# MSE is:  1792.552992675457
# r2_score is:  0.9488760940081715
