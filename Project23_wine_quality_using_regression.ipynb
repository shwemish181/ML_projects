# %% [markdown]
# This project was alraedy done as a part of projecr 14 wine data set but there we did classification into good and bad quality.Here we will try to predict the quality

# %%
#lets import the data set
import pandas as pd
df_wine=pd.read_csv('http://mlr.cs.umass.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv',sep=";")
df_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# 11              7.5             0.500         0.36             6.1      0.071
# 12              5.6             0.615         0.00             1.6      0.089
# 13              7.8             0.610         0.29             1.6      0.114
# 14              8.9             0.620         0.18             3.8      0.176
# 15              8.9             0.620         0.19             3.9      0.170
# 16              8.5             0.280         0.56             1.8      0.092
# 17              8.1             0.560         0.28             1.7      0.368
# 18              7.4             0.590         0.08             4.4      0.086
# 19              7.9             0.320         0.51             1.8      0.341
# 20              8.9             0.220         0.48             1.8      0.077
# 21              7.6             0.390         0.31             2.3      0.082
# 22              7.9             0.430         0.21             1.6      0.106
# 23              8.5             0.490         0.11             2.3      0.084
# 24              6.9             0.400         0.14             2.4      0.085
# 25              6.3             0.390         0.16             1.4      0.080
# 26              7.6             0.410         0.24             1.8      0.080
# 27              7.9             0.430         0.21             1.6      0.106
# 28              7.1             0.710         0.00             1.9      0.080
# 29              7.8             0.645         0.00             2.0      0.082
# ...             ...               ...          ...             ...        ...
# 1569            6.2             0.510         0.14             1.9      0.056
# 1570            6.4             0.360         0.53             2.2      0.230
# 1571            6.4             0.380         0.14             2.2      0.038
# 1572            7.3             0.690         0.32             2.2      0.069
# 1573            6.0             0.580         0.20             2.4      0.075
# 1574            5.6             0.310         0.78            13.9      0.074
# 1575            7.5             0.520         0.40             2.2      0.060
# 1576            8.0             0.300         0.63             1.6      0.081
# 1577            6.2             0.700         0.15             5.1      0.076
# 1578            6.8             0.670         0.15             1.8      0.118
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# 5         9.4        5
# 6         9.4        5
# 7        10.0        7
# 8         9.5        7
# 9        10.5        5
# 10        9.2        5
# 11       10.5        5
# 12        9.9        5
# 13        9.1        5
# 14        9.2        5
# 15        9.2        5
# 16       10.5        7
# 17        9.3        5
# 18        9.0        4
# 19        9.2        6
# 20        9.4        6
# 21        9.7        5
# 22        9.5        5
# 23        9.4        5
# 24        9.7        6
# 25        9.3        5
# 26        9.5        5
# 27        9.5        5
# 28        9.4        5
# 29        9.8        6
# ...       ...      ...
# 1569     11.5        6
# 1570     12.4        6
# 1571     11.1        6
# 1572      9.5        5
# 1573     12.5        6
# 1574     10.5        6
# 1575     11.8        6
# 1576     10.8        6
# 1577     11.9        6
# 1578     11.3        6
# 1579     11.3        5
# 1580     11.9        6
# 1581     11.3        5
# 1582     11.9        5
# 1583      9.8        5
# 1584     11.6        7
# 1585     11.5        6
# 1586     11.4        6
# 1587     10.9        6
# 1588     12.8        6
# 1589      9.2        5
# 1590     11.6        6
# 1591     11.6        6
# 1592     11.0        6
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
#Lets chcek the target variable value counts
df_wine["quality"].value_counts()
#Last time we divided the datset into good or bad quality wine,this tiem we will go for regression alogorithm to predict quality
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
#Lets chcek the correaltion matrix
df_wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
#lets chcek the null values
df_wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#lets divide the dataset into input and output dataset
df_x=df_wine.drop(columns=["quality"])
y=df_wine[["quality"]]

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,df_x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
#lets make a function which evaluates the model using cross_val_score
from sklearn.model_selection import cross_val_score
def model_evaluation(model,x,y):
    c_scores=cross_val_score(model,x,y,cv=5,scoring="r2")
    print("Mean r2 score for regressor: ",c_scores.mean())
    print("standard deviation in r2 score for regressor: ",c_scores.std())
    print(c_scores)

# %%
#lets make use of KNN regressor
#we will use pipeline to bring bring features to common scale
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
knr=KNeighborsRegressor()
pipeline=Pipeline([("ss",StandardScaler()),("knr",KNeighborsRegressor())])
parameters = {"knr__n_neighbors":range(2,30)}
clf = GridSearchCV(pipeline, parameters, cv=5,scoring="r2")
clf.fit(df_x, y)
clf.best_params_
# Out:
# F:\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'knr__n_neighbors': 29}

# %%
pipeline_knr=Pipeline([("ss",StandardScaler()),("knr",KNeighborsRegressor(n_neighbors=29))])
#knr=KNeighborsRegressor(n_neighbors=29)
maxr2_score(pipeline_knr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.3623867312637836
# r2 score corresponding to  43  is  0.325865472308695
# r2 score corresponding to  44  is  0.3287804535557596
# r2 score corresponding to  45  is  0.34996987464718754
# r2 score corresponding to  46  is  0.3127699846007115
# r2 score corresponding to  47  is  0.3588464796854719
# r2 score corresponding to  48  is  0.297974613552205
# r2 score corresponding to  49  is  0.30847621817871107
# r2 score corresponding to  50  is  0.30722273035455927
# r2 score corresponding to  51  is  0.2746587132928632
# r2 score corresponding to  52  is  0.31789224493856283
# r2 score corresponding to  53  is  0.3794818462682543
# r2 score corresponding to  54  is  0.34600497795161855
# r2 score corresponding to  55  is  0.3720434176847447
# r2 score corresponding to  56  is  0.3627865021116077
# r2 score corresponding to  57  is  0.31185218469342857
# r2 score corresponding to  58  is  0.3678533683043572
# r2 score corresponding to  59  is  0.2745639201911224
# r2 score corresponding to  60  is  0.3671893321922739
# r2 score corresponding to  61  is  0.3897112474327099
# r2 score corresponding to  62  is  0.3482934475887459
# r2 score corresponding to  63  is  0.35169248102296635
# r2 score corresponding to  64  is  0.25516044198777865
# r2 score corresponding to  65  is  0.32748901129209385
# r2 score corresponding to  66  is  0.2601291246391123
# r2 score corresponding to  67  is  0.3221577770345806
# r2 score corresponding to  68  is  0.3320963328265204
# r2 score corresponding to  69  is  0.34363787522740474
# r2 score corresponding to  70  is  0.3803810163131649
# r2 score corresponding to  71  is  0.3605239789596977
# r2 score corresponding to  72  is  0.28433943345771606
# r2 score corresponding to  73  is  0.2864373302359341
# r2 score corresponding to  74  is  0.31236031873825276
# r2 score corresponding to  75  is  0.3066682985711585
# r2 score corresponding to  76  is  0.3155875306303464
# r2 score corresponding to  77  is  0.3152184552648962
# r2 score corresponding to  78  is  0.3358836138765424
# r2 score corresponding to  79  is  0.3384002985952145
# r2 score corresponding to  80  is  0.26992448247678424
# r2 score corresponding to  81  is  0.3280191584122324
# r2 score corresponding to  82  is  0.33757435646691536
# r2 score corresponding to  83  is  0.36186561873788514
# r2 score corresponding to  84  is  0.3224091067518551
# r2 score corresponding to  85  is  0.32970138531218984
# r2 score corresponding to  86  is  0.3653788134239623
# r2 score corresponding to  87  is  0.19405167905593512
# r2 score corresponding to  88  is  0.25895255759982794
# r2 score corresponding to  89  is  0.38291740763147475
# r2 score corresponding to  90  is  0.3301770253074712
# r2 score corresponding to  91  is  0.3688536324769742
# r2 score corresponding to  92  is  0.3485818402191899
# r2 score corresponding to  93  is  0.3847390739570715
# r2 score corresponding to  94  is  0.2716492700529969
# r2 score corresponding to  95  is  0.3026548497145698
# r2 score corresponding to  96  is  0.3137275233199973
# r2 score corresponding to  97  is  0.30364225866843053
# r2 score corresponding to  98  is  0.29778742150277193
# r2 score corresponding to  99  is  0.31027333503392607
# max r2 score corresponding to  61  is  0.3897112474327099
# 61

# %%
#Lets use random forest regressor
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings("ignore")
rfr=RandomForestRegressor()
pipeline=Pipeline([("ss",StandardScaler()),("rfr",RandomForestRegressor())])
parameters = {"rfr__n_estimators":[10,100,500]}
clf = GridSearchCV(pipeline, parameters, cv=5,scoring="r2")
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'rfr__n_estimators': 500}

# %%
pipeline_rfr=Pipeline([("ss",StandardScaler()),("rfr",RandomForestRegressor(n_estimators=500))])
maxr2_score(pipeline_rfr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.5246575519658094
# r2 score corresponding to  43  is  0.47184473781454905
# r2 score corresponding to  44  is  0.43637321404607465
# r2 score corresponding to  45  is  0.47861077368638805
# r2 score corresponding to  46  is  0.490694357335684
# r2 score corresponding to  47  is  0.48724703227262467
# r2 score corresponding to  48  is  0.46258243948019595
# r2 score corresponding to  49  is  0.5048301733296512
# r2 score corresponding to  50  is  0.45740415733263884
# r2 score corresponding to  51  is  0.3934577927386391
# r2 score corresponding to  52  is  0.48883440557744773
# r2 score corresponding to  53  is  0.5193901921756111
# r2 score corresponding to  54  is  0.49762233562315994
# r2 score corresponding to  55  is  0.48289942968457333
# r2 score corresponding to  56  is  0.4965120394088671
# r2 score corresponding to  57  is  0.4312627374384569
# r2 score corresponding to  58  is  0.5141981578426326
# r2 score corresponding to  59  is  0.45356236493374114
# r2 score corresponding to  60  is  0.500360249134948
# r2 score corresponding to  61  is  0.5817283712121213
# r2 score corresponding to  62  is  0.5055642311459354
# r2 score corresponding to  63  is  0.4758334780198695
# r2 score corresponding to  64  is  0.4710806162876009
# r2 score corresponding to  65  is  0.5459694170181095
# r2 score corresponding to  66  is  0.4427657510590248
# r2 score corresponding to  67  is  0.5293711528043208
# r2 score corresponding to  68  is  0.4747649951680447
# r2 score corresponding to  69  is  0.5166986728652492
# r2 score corresponding to  70  is  0.5036991392879652
# r2 score corresponding to  71  is  0.5210436755249089
# r2 score corresponding to  72  is  0.489770045225442
# r2 score corresponding to  73  is  0.44719239542121647
# r2 score corresponding to  74  is  0.5069035966783138
# r2 score corresponding to  75  is  0.38051600239377625
# r2 score corresponding to  76  is  0.4651338302215733
# r2 score corresponding to  77  is  0.4796253775520599
# r2 score corresponding to  78  is  0.5192645879652782
# r2 score corresponding to  79  is  0.46500567082831623
# r2 score corresponding to  80  is  0.4133308033140618
# r2 score corresponding to  81  is  0.4852699331357686
# r2 score corresponding to  82  is  0.4524622934466057
# r2 score corresponding to  83  is  0.5612997962802833
# r2 score corresponding to  84  is  0.46997791260126554
# r2 score corresponding to  85  is  0.44270214509156647
# r2 score corresponding to  86  is  0.5213370348258706
# r2 score corresponding to  87  is  0.37169468276075524
# r2 score corresponding to  88  is  0.43429093584388057
# r2 score corresponding to  89  is  0.4963440191974998
# r2 score corresponding to  90  is  0.4747924338354882
# r2 score corresponding to  91  is  0.4881780194049332
# r2 score corresponding to  92  is  0.5448999508130008
# r2 score corresponding to  93  is  0.5424213584309988
# r2 score corresponding to  94  is  0.4525806425902865
# r2 score corresponding to  95  is  0.43059037999509675
# r2 score corresponding to  96  is  0.458963442808607
# r2 score corresponding to  97  is  0.4898720475852594
# r2 score corresponding to  98  is  0.43077765612665253
# r2 score corresponding to  99  is  0.4662603100115851
# max r2 score corresponding to  61  is  0.5817283712121213
# 61

# %%
#lets chcek the cross_val_score for random forest
print("RANDOM FOREST\n\n")
model_evaluation(pipeline_rfr,df_x,y)
# Out:
# RANDOM FOREST
#
#
# Mean r2 score for regressor:  0.3180266244336236
# standard deviation in r2 score for regressor:  0.04265447392973599
# [0.2621275  0.36191517 0.36517449 0.32501271 0.27590325]

# %%
#lets make the final model and save it
x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = 61,test_size=0.20)
pipeline_rfr.fit(x_train,y_train)
y_pred = pipeline_rfr.predict(x_test)

# %%
#Lets find the rmse and r2_score using sklearn.metrics for random forest model
print("MSE is: ",mean_squared_error(y_test,y_pred))
print("r2_score is: ",r2_score(y_test,y_pred))
# Out:
# MSE is:  0.27995626250000005
# r2_score is:  0.5758238446969696
